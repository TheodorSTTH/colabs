# %% [markdown]
# <a href="https://colab.research.google.com/github/TheodorSTTH/colabs/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ymsyg8u_
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ymsyg8u_
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14625 sha256=b3997a7fb193f198a53f41e60531c631405dc5ed3b88d3ad8a3745d7bf872d1b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-di5kyete/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.305621, train error 89.57,  test loss 2.305353, test error 89.82
# Epoch   100, train loss 1.875245, train error 70.12,  test loss 1.739040, test error 68.07
# Epoch   200, train loss 1.860174, train error 70.00,  test loss 1.714882, test error 68.45
# Epoch   300, train loss 1.851088, train error 69.95,  test loss 1.709772, test error 68.22
# Epoch   400, train loss 1.858856, train error 69.93,  test loss 1.725053, test error 68.47
# Epoch   500, train loss 1.850334, train error 70.22,  test loss 1.714543, test error 68.03
# Epoch   600, train loss 1.846685, train error 69.30,  test loss 1.703976, test error 68.00
# Epoch   700, train loss 1.846510, train error 70.28,  test loss 1.708289, test error 67.75
# Epoch   800, train loss 1.846974, train error 69.70,  test loss 1.704107, test error 68.40
# Epoch   900, train loss 1.846318, train error 69.60,  test loss 1.702596, test error 67.85
# Training model with   4 hidden variables
# Epoch     0, train loss 2.300807, train error 90.05,  test loss 2.307514, test error 90.18
# Epoch   100, train loss 1.760149, train error 64.12,  test loss 1.582106, test error 61.03
# Epoch   200, train loss 1.747644, train error 63.65,  test loss 1.579498, test error 61.25
# Epoch   300, train loss 1.745189, train error 63.70,  test loss 1.578036, test error 61.10
# Epoch   400, train loss 1.743361, train error 63.30,  test loss 1.586004, test error 61.85
# Epoch   500, train loss 1.739084, train error 63.50,  test loss 1.582895, test error 61.03
# Epoch   600, train loss 1.738169, train error 63.55,  test loss 1.582943, test error 61.58
# Epoch   700, train loss 1.740215, train error 63.83,  test loss 1.586664, test error 61.70
# Epoch   800, train loss 1.734352, train error 63.72,  test loss 1.589696, test error 61.70
# Epoch   900, train loss 1.736092, train error 63.22,  test loss 1.591318, test error 61.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.248041, train error 85.20,  test loss 2.240531, test error 85.03
# Epoch   100, train loss 1.650878, train error 58.95,  test loss 1.444876, test error 56.17
# Epoch   200, train loss 1.630187, train error 58.62,  test loss 1.447042, test error 55.83
# Epoch   300, train loss 1.618579, train error 57.45,  test loss 1.436832, test error 54.22
# Epoch   400, train loss 1.610415, train error 57.65,  test loss 1.435782, test error 55.17
# Epoch   500, train loss 1.601782, train error 58.03,  test loss 1.441717, test error 55.00
# Epoch   600, train loss 1.600160, train error 56.92,  test loss 1.447896, test error 55.17
# Epoch   700, train loss 1.606024, train error 57.67,  test loss 1.451145, test error 57.05
# Epoch   800, train loss 1.595108, train error 57.42,  test loss 1.447267, test error 55.67
# Epoch   900, train loss 1.590651, train error 57.47,  test loss 1.443034, test error 55.65
# Training model with   8 hidden variables
# Epoch     0, train loss 2.302056, train error 88.35,  test loss 2.305574, test error 88.20
# Epoch   100, train loss 1.626359, train error 55.67,  test loss 1.455143, test error 55.85
# Epoch   200, train loss 1.581835, train error 54.12,  test loss 1.418246, test error 54.95
# Epoch   300, train loss 1.554631, train error 54.12,  test loss 1.399709, test error 53.90
# Epoch   400, train loss 1.540106, train error 54.42,  test loss 1.406206, test error 54.55
# Epoch   500, train loss 1.528707, train error 53.58,  test loss 1.417736, test error 54.30
# Epoch   600, train loss 1.524113, train error 52.97,  test loss 1.407034, test error 54.00
# Epoch   700, train loss 1.522887, train error 53.45,  test loss 1.413734, test error 54.22
# Epoch   800, train loss 1.520075, train error 54.20,  test loss 1.430206, test error 54.62
# Epoch   900, train loss 1.515108, train error 53.03,  test loss 1.426277, test error 54.20
# Training model with  10 hidden variables
# Epoch     0, train loss 2.257131, train error 84.38,  test loss 2.252946, test error 85.05
# Epoch   100, train loss 1.490924, train error 51.45,  test loss 1.331991, test error 48.58
# Epoch   200, train loss 1.445365, train error 49.65,  test loss 1.310995, test error 49.17
# Epoch   300, train loss 1.425012, train error 49.62,  test loss 1.320913, test error 49.67
# Epoch   400, train loss 1.416514, train error 48.75,  test loss 1.333754, test error 49.40
# Epoch   500, train loss 1.418302, train error 49.20,  test loss 1.339970, test error 49.58
# Epoch   600, train loss 1.406991, train error 49.42,  test loss 1.340860, test error 49.60
# Epoch   700, train loss 1.403898, train error 48.97,  test loss 1.344954, test error 49.42
# Epoch   800, train loss 1.402251, train error 48.45,  test loss 1.344130, test error 49.70
# Epoch   900, train loss 1.393186, train error 47.72,  test loss 1.350186, test error 49.22
# Training model with  14 hidden variables
# Epoch     0, train loss 2.217994, train error 81.93,  test loss 2.238278, test error 83.88
# Epoch   100, train loss 1.505339, train error 51.83,  test loss 1.441565, test error 55.90
# Epoch   200, train loss 1.416368, train error 48.92,  test loss 1.430365, test error 53.72
# Epoch   300, train loss 1.369954, train error 46.58,  test loss 1.438933, test error 53.45
# Epoch   400, train loss 1.349591, train error 46.50,  test loss 1.465120, test error 53.42
# Epoch   500, train loss 1.341141, train error 46.08,  test loss 1.491668, test error 54.78
# Epoch   600, train loss 1.335858, train error 46.15,  test loss 1.489638, test error 54.38
# Epoch   700, train loss 1.326252, train error 46.08,  test loss 1.503753, test error 53.97
# Epoch   800, train loss 1.328625, train error 45.83,  test loss 1.513897, test error 53.62
# Epoch   900, train loss 1.308266, train error 44.78,  test loss 1.532084, test error 54.50
# Training model with  18 hidden variables
# Epoch     0, train loss 2.207457, train error 81.45,  test loss 2.175121, test error 81.43
# Epoch   100, train loss 1.334569, train error 44.58,  test loss 1.296923, test error 48.33
# Epoch   200, train loss 1.241741, train error 40.38,  test loss 1.317477, test error 48.60
# Epoch   300, train loss 1.189578, train error 38.67,  test loss 1.329491, test error 47.95
# Epoch   400, train loss 1.185963, train error 39.12,  test loss 1.371964, test error 48.15
# Epoch   500, train loss 1.163275, train error 38.22,  test loss 1.378455, test error 48.25
# Epoch   600, train loss 1.147174, train error 38.20,  test loss 1.395718, test error 48.80
# Epoch   700, train loss 1.135690, train error 37.62,  test loss 1.411469, test error 49.38
# Epoch   800, train loss 1.128109, train error 37.88,  test loss 1.426785, test error 49.38
# Epoch   900, train loss 1.126874, train error 37.97,  test loss 1.458295, test error 50.03
# Training model with  22 hidden variables
# Epoch     0, train loss 2.172227, train error 81.03,  test loss 2.140181, test error 79.68
# Epoch   100, train loss 1.290113, train error 42.47,  test loss 1.310198, test error 48.92
# Epoch   200, train loss 1.160226, train error 39.15,  test loss 1.379688, test error 49.95
# Epoch   300, train loss 1.114342, train error 36.90,  test loss 1.436477, test error 51.03
# Epoch   400, train loss 1.074006, train error 35.93,  test loss 1.500855, test error 50.90
# Epoch   500, train loss 1.042428, train error 34.15,  test loss 1.556707, test error 50.95
# Epoch   600, train loss 1.031276, train error 34.57,  test loss 1.605430, test error 50.78
# Epoch   700, train loss 1.030516, train error 34.30,  test loss 1.672123, test error 51.88
# Epoch   800, train loss 1.012798, train error 33.82,  test loss 1.702316, test error 51.15
# Epoch   900, train loss 0.996566, train error 33.00,  test loss 1.740131, test error 51.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.130085, train error 77.50,  test loss 2.083598, test error 76.30
# Epoch   100, train loss 1.166027, train error 38.65,  test loss 1.287964, test error 47.03
# Epoch   200, train loss 1.039657, train error 33.97,  test loss 1.427192, test error 48.78
# Epoch   300, train loss 0.961703, train error 31.80,  test loss 1.494967, test error 49.45
# Epoch   400, train loss 0.914919, train error 30.70,  test loss 1.585301, test error 51.20
# Epoch   500, train loss 0.881045, train error 29.47,  test loss 1.682343, test error 50.40
# Epoch   600, train loss 0.862166, train error 28.97,  test loss 1.739496, test error 51.95
# Epoch   700, train loss 0.847609, train error 28.57,  test loss 1.820078, test error 52.42
# Epoch   800, train loss 0.830554, train error 28.35,  test loss 1.902550, test error 53.88
# Epoch   900, train loss 0.831650, train error 28.82,  test loss 1.984538, test error 53.97
# Training model with  30 hidden variables
# Epoch     0, train loss 2.142366, train error 79.45,  test loss 2.101687, test error 78.12
# Epoch   100, train loss 1.118434, train error 37.65,  test loss 1.341234, test error 49.55
# Epoch   200, train loss 0.934829, train error 30.45,  test loss 1.532535, test error 51.28
# Epoch   300, train loss 0.844181, train error 27.20,  test loss 1.724775, test error 52.17
# Epoch   400, train loss 0.810690, train error 28.12,  test loss 1.979999, test error 55.75
# Epoch   500, train loss 0.741962, train error 24.70,  test loss 2.082994, test error 54.25
# Epoch   600, train loss 0.712971, train error 23.68,  test loss 2.210560, test error 54.80
# Epoch   700, train loss 0.686616, train error 23.12,  test loss 2.366204, test error 55.35
# Epoch   800, train loss 0.681243, train error 23.30,  test loss 2.482769, test error 55.50
# Epoch   900, train loss 0.678688, train error 23.22,  test loss 2.571826, test error 55.47
# Training model with  35 hidden variables
# Epoch     0, train loss 2.202132, train error 80.65,  test loss 2.200974, test error 82.35
# Epoch   100, train loss 1.012981, train error 33.60,  test loss 1.409795, test error 50.42
# Epoch   200, train loss 0.794025, train error 26.80,  test loss 1.721154, test error 51.85
# Epoch   300, train loss 0.652758, train error 22.00,  test loss 2.118092, test error 53.83
# Epoch   400, train loss 0.595091, train error 20.90,  test loss 2.491762, test error 54.28
# Epoch   500, train loss 0.533840, train error 18.35,  test loss 2.962871, test error 55.42
# Epoch   600, train loss 0.481173, train error 16.62,  test loss 3.349742, test error 56.42
# Epoch   700, train loss 0.457020, train error 15.40,  test loss 3.697547, test error 56.28
# Epoch   800, train loss 0.441567, train error 15.43,  test loss 4.026818, test error 55.92
# Epoch   900, train loss 0.397463, train error 13.75,  test loss 4.427956, test error 56.75
# Training model with  40 hidden variables
# Epoch     0, train loss 2.080648, train error 76.93,  test loss 2.025253, test error 77.60
# Epoch   100, train loss 0.899116, train error 28.62,  test loss 1.489511, test error 50.62
# Epoch   200, train loss 0.639121, train error 20.25,  test loss 1.971766, test error 51.83
# Epoch   300, train loss 0.508673, train error 17.05,  test loss 2.570536, test error 55.28
# Epoch   400, train loss 0.409720, train error 14.12,  test loss 3.284871, test error 55.97
# Epoch   500, train loss 0.370042, train error 12.75,  test loss 3.925998, test error 55.67
# Epoch   600, train loss 0.313088, train error 11.22,  test loss 4.658886, test error 57.20
# Epoch   700, train loss 0.308553, train error 11.60,  test loss 5.446174, test error 57.17
# Epoch   800, train loss 0.336131, train error 12.57,  test loss 6.017568, test error 56.25
# Epoch   900, train loss 0.330890, train error 11.85,  test loss 6.507424, test error 56.15
# Training model with  45 hidden variables
# Epoch     0, train loss 2.044831, train error 77.62,  test loss 2.000109, test error 77.60
# Epoch   100, train loss 0.820241, train error 26.05,  test loss 1.502763, test error 49.03
# Epoch   200, train loss 0.462596, train error 13.88,  test loss 2.259630, test error 52.80
# Epoch   300, train loss 0.274842, train error 8.25,  test loss 3.364340, test error 53.97
# Epoch   400, train loss 0.162986, train error 4.22,  test loss 4.666312, test error 54.85
# Epoch   500, train loss 0.146333, train error 4.75,  test loss 5.953396, test error 55.03
# Epoch   600, train loss 0.128839, train error 4.00,  test loss 7.152561, test error 55.55
# Epoch   700, train loss 0.010267, train error 0.00,  test loss 8.071215, test error 55.72
# Epoch   800, train loss 0.006719, train error 0.00,  test loss 8.637881, test error 55.65
# Epoch   900, train loss 0.005113, train error 0.00,  test loss 9.070681, test error 55.62
# Training model with  50 hidden variables
# Epoch     0, train loss 2.117661, train error 78.40,  test loss 2.104825, test error 78.62
# Epoch   100, train loss 0.697175, train error 22.05,  test loss 1.461559, test error 47.55
# Epoch   200, train loss 0.333526, train error 9.65,  test loss 2.515529, test error 50.92
# Epoch   300, train loss 0.140785, train error 3.12,  test loss 3.913068, test error 52.55
# Epoch   400, train loss 0.100769, train error 3.10,  test loss 5.377265, test error 52.85
# Epoch   500, train loss 0.012159, train error 0.00,  test loss 6.297592, test error 53.75
# Epoch   600, train loss 0.007562, train error 0.00,  test loss 6.859493, test error 53.53
# Epoch   700, train loss 0.005435, train error 0.00,  test loss 7.284399, test error 53.72
# Epoch   800, train loss 0.004222, train error 0.00,  test loss 7.621585, test error 53.80
# Epoch   900, train loss 0.003419, train error 0.00,  test loss 7.898623, test error 53.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.074067, train error 77.80,  test loss 2.029530, test error 77.20
# Epoch   100, train loss 0.671412, train error 20.55,  test loss 1.589451, test error 50.22
# Epoch   200, train loss 0.223248, train error 5.15,  test loss 2.885630, test error 53.62
# Epoch   300, train loss 0.040987, train error 0.10,  test loss 4.574897, test error 54.70
# Epoch   400, train loss 0.014108, train error 0.00,  test loss 5.635260, test error 55.15
# Epoch   500, train loss 0.008161, train error 0.00,  test loss 6.247770, test error 55.60
# Epoch   600, train loss 0.005633, train error 0.00,  test loss 6.693238, test error 55.67
# Epoch   700, train loss 0.004199, train error 0.00,  test loss 7.023419, test error 55.80
# Epoch   800, train loss 0.003323, train error 0.00,  test loss 7.304852, test error 55.78
# Epoch   900, train loss 0.002713, train error 0.00,  test loss 7.538739, test error 55.78
# Training model with  60 hidden variables
# Epoch     0, train loss 2.101291, train error 77.90,  test loss 2.063192, test error 77.60
# Epoch   100, train loss 0.522512, train error 15.85,  test loss 1.812763, test error 51.92
# Epoch   200, train loss 0.092158, train error 0.72,  test loss 3.503138, test error 54.22
# Epoch   300, train loss 0.018725, train error 0.00,  test loss 4.843112, test error 54.35
# Epoch   400, train loss 0.009196, train error 0.00,  test loss 5.533136, test error 54.70
# Epoch   500, train loss 0.005923, train error 0.00,  test loss 5.981756, test error 54.95
# Epoch   600, train loss 0.004222, train error 0.00,  test loss 6.315509, test error 54.88
# Epoch   700, train loss 0.003260, train error 0.00,  test loss 6.583364, test error 54.95
# Epoch   800, train loss 0.002608, train error 0.00,  test loss 6.808861, test error 55.00
# Epoch   900, train loss 0.002170, train error 0.00,  test loss 7.000259, test error 54.90
# Training model with  70 hidden variables
# Epoch     0, train loss 2.049901, train error 75.30,  test loss 2.001128, test error 74.40
# Epoch   100, train loss 0.339473, train error 8.12,  test loss 1.953948, test error 51.33
# Epoch   200, train loss 0.029891, train error 0.00,  test loss 3.542952, test error 52.72
# Epoch   300, train loss 0.010470, train error 0.00,  test loss 4.271320, test error 52.67
# Epoch   400, train loss 0.005856, train error 0.00,  test loss 4.686858, test error 52.67
# Epoch   500, train loss 0.003968, train error 0.00,  test loss 4.982145, test error 52.55
# Epoch   600, train loss 0.002949, train error 0.00,  test loss 5.203800, test error 52.70
# Epoch   700, train loss 0.002318, train error 0.00,  test loss 5.385918, test error 52.53
# Epoch   800, train loss 0.001900, train error 0.00,  test loss 5.538112, test error 52.75
# Epoch   900, train loss 0.001599, train error 0.00,  test loss 5.669187, test error 52.75
# Training model with  80 hidden variables
# Epoch     0, train loss 2.046323, train error 75.57,  test loss 1.987364, test error 75.30
# Epoch   100, train loss 0.228721, train error 3.60,  test loss 2.026972, test error 51.17
# Epoch   200, train loss 0.020437, train error 0.00,  test loss 3.369403, test error 52.75
# Epoch   300, train loss 0.008237, train error 0.00,  test loss 3.915033, test error 52.75
# Epoch   400, train loss 0.004902, train error 0.00,  test loss 4.241796, test error 53.08
# Epoch   500, train loss 0.003376, train error 0.00,  test loss 4.475751, test error 53.03
# Epoch   600, train loss 0.002538, train error 0.00,  test loss 4.654077, test error 53.25
# Epoch   700, train loss 0.002016, train error 0.00,  test loss 4.801442, test error 53.15
# Epoch   800, train loss 0.001661, train error 0.00,  test loss 4.923101, test error 53.15
# Epoch   900, train loss 0.001405, train error 0.00,  test loss 5.029531, test error 53.10
# Training model with  90 hidden variables
# Epoch     0, train loss 2.023524, train error 74.35,  test loss 1.977396, test error 75.00
# Epoch   100, train loss 0.165019, train error 1.88,  test loss 2.234621, test error 52.75
# Epoch   200, train loss 0.015113, train error 0.00,  test loss 3.390700, test error 52.97
# Epoch   300, train loss 0.006574, train error 0.00,  test loss 3.859087, test error 53.05
# Epoch   400, train loss 0.004009, train error 0.00,  test loss 4.148432, test error 53.03
# Epoch   500, train loss 0.002810, train error 0.00,  test loss 4.358171, test error 52.85
# Epoch   600, train loss 0.002136, train error 0.00,  test loss 4.519287, test error 52.88
# Epoch   700, train loss 0.001712, train error 0.00,  test loss 4.653213, test error 53.20
# Epoch   800, train loss 0.001414, train error 0.00,  test loss 4.764633, test error 53.25
# Epoch   900, train loss 0.001201, train error 0.00,  test loss 4.861179, test error 53.38
# Training model with 100 hidden variables
# Epoch     0, train loss 1.997239, train error 73.35,  test loss 1.928522, test error 74.80
# Epoch   100, train loss 0.087731, train error 0.25,  test loss 2.273838, test error 50.62
# Epoch   200, train loss 0.011715, train error 0.00,  test loss 3.102791, test error 51.08
# Epoch   300, train loss 0.005502, train error 0.00,  test loss 3.465608, test error 51.05
# Epoch   400, train loss 0.003435, train error 0.00,  test loss 3.688002, test error 51.10
# Epoch   500, train loss 0.002441, train error 0.00,  test loss 3.851439, test error 51.05
# Epoch   600, train loss 0.001873, train error 0.00,  test loss 3.982678, test error 51.08
# Epoch   700, train loss 0.001507, train error 0.00,  test loss 4.087622, test error 51.03
# Epoch   800, train loss 0.001253, train error 0.00,  test loss 4.179111, test error 50.92
# Epoch   900, train loss 0.001067, train error 0.00,  test loss 4.256956, test error 51.00
# Training model with 120 hidden variables
# Epoch     0, train loss 2.009276, train error 74.88,  test loss 1.959780, test error 75.55
# Epoch   100, train loss 0.052567, train error 0.03,  test loss 2.203124, test error 49.38
# Epoch   200, train loss 0.009593, train error 0.00,  test loss 2.829486, test error 49.88
# Epoch   300, train loss 0.004714, train error 0.00,  test loss 3.105529, test error 50.28
# Epoch   400, train loss 0.003008, train error 0.00,  test loss 3.286314, test error 50.22
# Epoch   500, train loss 0.002165, train error 0.00,  test loss 3.417947, test error 50.25
# Epoch   600, train loss 0.001671, train error 0.00,  test loss 3.524656, test error 50.20
# Epoch   700, train loss 0.001350, train error 0.00,  test loss 3.612579, test error 50.33
# Epoch   800, train loss 0.001126, train error 0.00,  test loss 3.686403, test error 50.35
# Epoch   900, train loss 0.000961, train error 0.00,  test loss 3.750481, test error 50.40
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952762, train error 72.43,  test loss 1.886418, test error 74.07
# Epoch   100, train loss 0.034815, train error 0.00,  test loss 2.145434, test error 50.08
# Epoch   200, train loss 0.008023, train error 0.00,  test loss 2.626630, test error 50.03
# Epoch   300, train loss 0.004114, train error 0.00,  test loss 2.847445, test error 50.10
# Epoch   400, train loss 0.002679, train error 0.00,  test loss 2.994190, test error 50.03
# Epoch   500, train loss 0.001950, train error 0.00,  test loss 3.102232, test error 49.97
# Epoch   600, train loss 0.001516, train error 0.00,  test loss 3.189756, test error 49.90
# Epoch   700, train loss 0.001231, train error 0.00,  test loss 3.262202, test error 49.90
# Epoch   800, train loss 0.001032, train error 0.00,  test loss 3.323569, test error 49.85
# Epoch   900, train loss 0.000884, train error 0.00,  test loss 3.377687, test error 49.85
# Training model with 160 hidden variables
# Epoch     0, train loss 1.933003, train error 70.80,  test loss 1.865394, test error 72.40
# Epoch   100, train loss 0.029041, train error 0.00,  test loss 2.100080, test error 48.60
# Epoch   200, train loss 0.007146, train error 0.00,  test loss 2.502280, test error 48.92
# Epoch   300, train loss 0.003766, train error 0.00,  test loss 2.702588, test error 48.78
# Epoch   400, train loss 0.002467, train error 0.00,  test loss 2.836040, test error 48.95
# Epoch   500, train loss 0.001806, train error 0.00,  test loss 2.934718, test error 48.80
# Epoch   600, train loss 0.001409, train error 0.00,  test loss 3.014255, test error 48.85
# Epoch   700, train loss 0.001147, train error 0.00,  test loss 3.079057, test error 48.80
# Epoch   800, train loss 0.000963, train error 0.00,  test loss 3.135397, test error 48.90
# Epoch   900, train loss 0.000826, train error 0.00,  test loss 3.184582, test error 48.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.929422, train error 72.03,  test loss 1.867513, test error 71.93
# Epoch   100, train loss 0.024308, train error 0.00,  test loss 2.043187, test error 48.12
# Epoch   200, train loss 0.006557, train error 0.00,  test loss 2.386817, test error 48.25
# Epoch   300, train loss 0.003515, train error 0.00,  test loss 2.561507, test error 48.15
# Epoch   400, train loss 0.002330, train error 0.00,  test loss 2.678968, test error 48.15
# Epoch   500, train loss 0.001716, train error 0.00,  test loss 2.767289, test error 48.17
# Epoch   600, train loss 0.001344, train error 0.00,  test loss 2.837557, test error 48.12
# Epoch   700, train loss 0.001098, train error 0.00,  test loss 2.895925, test error 47.95
# Epoch   800, train loss 0.000924, train error 0.00,  test loss 2.946719, test error 47.88
# Epoch   900, train loss 0.000794, train error 0.00,  test loss 2.990828, test error 47.90
# Training model with 200 hidden variables
# Epoch     0, train loss 1.935817, train error 70.25,  test loss 1.848947, test error 71.80
# Epoch   100, train loss 0.021351, train error 0.00,  test loss 2.020450, test error 47.55
# Epoch   200, train loss 0.006055, train error 0.00,  test loss 2.336227, test error 47.72
# Epoch   300, train loss 0.003294, train error 0.00,  test loss 2.499574, test error 47.80
# Epoch   400, train loss 0.002199, train error 0.00,  test loss 2.609655, test error 47.83
# Epoch   500, train loss 0.001626, train error 0.00,  test loss 2.692311, test error 47.88
# Epoch   600, train loss 0.001278, train error 0.00,  test loss 2.758468, test error 47.88
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.813611, test error 47.90
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.861243, test error 48.00
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.902674, test error 48.05
# Training model with 250 hidden variables
# Epoch     0, train loss 1.875724, train error 67.53,  test loss 1.802016, test error 69.55
# Epoch   100, train loss 0.016835, train error 0.00,  test loss 1.932405, test error 47.17
# Epoch   200, train loss 0.005318, train error 0.00,  test loss 2.187186, test error 47.12
# Epoch   300, train loss 0.002957, train error 0.00,  test loss 2.323005, test error 46.97
# Epoch   400, train loss 0.001999, train error 0.00,  test loss 2.415741, test error 47.00
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.486256, test error 46.97
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.542189, test error 47.03
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.589672, test error 47.03
# Epoch   800, train loss 0.000815, train error 0.00,  test loss 2.630101, test error 46.95
# Epoch   900, train loss 0.000703, train error 0.00,  test loss 2.666038, test error 46.97
# Training model with 300 hidden variables
# Epoch     0, train loss 1.878814, train error 69.00,  test loss 1.791936, test error 69.60
# Epoch   100, train loss 0.014909, train error 0.00,  test loss 1.859504, test error 46.45
# Epoch   200, train loss 0.004904, train error 0.00,  test loss 2.076084, test error 46.70
# Epoch   300, train loss 0.002774, train error 0.00,  test loss 2.193450, test error 46.53
# Epoch   400, train loss 0.001887, train error 0.00,  test loss 2.273161, test error 46.40
# Epoch   500, train loss 0.001411, train error 0.00,  test loss 2.334563, test error 46.28
# Epoch   600, train loss 0.001117, train error 0.00,  test loss 2.384010, test error 46.28
# Epoch   700, train loss 0.000919, train error 0.00,  test loss 2.425321, test error 46.38
# Epoch   800, train loss 0.000778, train error 0.00,  test loss 2.461109, test error 46.38
# Epoch   900, train loss 0.000672, train error 0.00,  test loss 2.492513, test error 46.33
# Training model with 400 hidden variables
# Epoch     0, train loss 1.827783, train error 66.00,  test loss 1.775124, test error 69.95
# Epoch   100, train loss 0.011589, train error 0.00,  test loss 1.751397, test error 46.08
# Epoch   200, train loss 0.004140, train error 0.00,  test loss 1.925522, test error 46.03
# Epoch   300, train loss 0.002397, train error 0.00,  test loss 2.023805, test error 46.03
# Epoch   400, train loss 0.001652, train error 0.00,  test loss 2.091444, test error 46.03
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.143553, test error 45.95
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.186081, test error 46.03
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.221759, test error 45.97
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.252318, test error 45.90
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.279529, test error 45.95

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
